# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabhk1501/Data-Analytics-Tasks/blob/main/session_17_tasks_soln.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
# Out:
# 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'

# %%
import numpy as np
import pandas as pd

# %%
# reading a tab separated file
item_df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')

# %%
item_df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# ## Basic DataFrame
#
# Consider the following Python dictionary data and Python list labels:
#
# ```
# data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills', 'Cranes'],
#         'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4, 3.5], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2, 2],
#         'priority': ['yes', 'yes', 'no', np.nan, 'no', 'no', 'no', 'yes', 'no', 'no','yes']}
# ```
# ```
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']
# ```

# %% [markdown]
# ###`Q-1:`
# i. Create a DataFrame birds from the above dictionary data which has the index labels.
#
# ii. Display basic information about the dataFrame.
#
# iii. Show Alternate rows of the dataframe.

# %%
data = {'birds': ['Cranes', 'Cranes', 'plovers', 'spoonbills', 'spoonbills', 'Cranes', 'plovers', 'Cranes', 'spoonbills', 'spoonbills', 'Cranes'],
        'age': [3.5, 4, 1.5, np.nan, 6, 3, 5.5, np.nan, 8, 4, 3.5], 'visits': [2, 4, 3, 4, 3, 4, 2, 2, 3, 2, 2],
        'priority': ['yes', 'yes', 'no', np.nan, 'no', 'no', 'no', 'yes', 'no', 'no','yes']}

# %%
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k']

# %%
# code here

birds = pd.DataFrame(data,index=labels)

# %%
birds
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# b      Cranes  4.0       4      yes
# c     plovers  1.5       3       no
# d  spoonbills  NaN       4      NaN
# e  spoonbills  6.0       3       no
# f      Cranes  3.0       4       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
# k      Cranes  3.5       2      yes

# %%
birds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, a to k
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   birds     11 non-null     object
#  1   age       9 non-null      float64
#  2   visits    11 non-null     int64
#  3   priority  10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 440.0+ bytes

# %%
birds.describe()
# Out:
#             age     visits
# count  9.000000  11.000000
# mean   4.333333   2.818182
# std    1.903943   0.873863
# min    1.500000   2.000000
# 25%    3.500000   2.000000
# 50%    4.000000   3.000000
# 75%    5.500000   3.500000
# max    8.000000   4.000000

# %%
#alternate rows
#first alternate
birds.iloc[::2,:]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# i  spoonbills  8.0       3       no
# k      Cranes  3.5       2      yes

# %%
# second alternate

birds.iloc[1::2,:]
# Out:
#         birds  age  visits priority
# b      Cranes  4.0       4      yes
# d  spoonbills  NaN       4      NaN
# f      Cranes  3.0       4       no
# h      Cranes  NaN       2      yes
# j  spoonbills  4.0       2       no

# %% [markdown]
# ###`Q-2:`
# i. Show only rows [1st, 3rd, 7th] from columns ['bird', 'age']
#
# ii. Select rows where the number of visits is less than 4.

# %%
# code here

birds.reset_index().loc[[0,2,6],['birds','age']]
# Out:
#      birds  age
# 0   Cranes  3.5
# 2  plovers  1.5
# 6  plovers  5.5

# %%
birds[birds['visits'] < 4]
# Out:
#         birds  age  visits priority
# a      Cranes  3.5       2      yes
# c     plovers  1.5       3       no
# e  spoonbills  6.0       3       no
# g     plovers  5.5       2       no
# h      Cranes  NaN       2      yes
# i  spoonbills  8.0       3       no
# j  spoonbills  4.0       2       no
# k      Cranes  3.5       2      yes

# %% [markdown]
# ###`Q-3:`
# i. Select all rows with nan values in age and visits column.
#
# ii. Fill nan with respective series mode value.

# %%
# code here

birds[(birds['age'].isnull()) | (birds['visits'].isnull())]
# Out:
#         birds  age  visits priority
# d  spoonbills  NaN       4      NaN
# h      Cranes  NaN       2      yes

# %%
birds['age'].mean()
# Out:
# 4.333333333333333

# %%
birds.isnull().sum()
# Out:
# birds       0
# age         2
# visits      0
# priority    1
# dtype: int64

# %%
birds['age'].fillna(birds['age'].mean(),inplace=True)

# %%
birds['priority'].fillna(birds['priority'].mode(),inplace=True)

# %%
birds['priority'].mode()
# Out:
# 0    no
# Name: priority, dtype: object

# %%
birds['priority'].fillna(birds['priority'].mode()[0])
# Out:
# a    yes
# b    yes
# c     no
# d     no
# e     no
# f     no
# g     no
# h    yes
# i     no
# j     no
# k    yes
# Name: priority, dtype: object

# %%
birds
# Out:
#         birds       age  visits priority
# a      Cranes  3.500000       2      yes
# b      Cranes  4.000000       4      yes
# c     plovers  1.500000       3       no
# d  spoonbills  4.333333       4      NaN
# e  spoonbills  6.000000       3       no
# f      Cranes  3.000000       4       no
# g     plovers  5.500000       2       no
# h      Cranes  4.333333       2      yes
# i  spoonbills  8.000000       3       no
# j  spoonbills  4.000000       2       no
# k      Cranes  3.500000       2      yes

# %%
birds['priority'].value_counts()[0]
# Out:
# 6

# %% [markdown]
# ###`Q-4`
# i. Find the total number of visits of the bird Cranes
#
# ii. Find the number of each type of birds in dataframe.
#
# iii. Print no of duplicate rows
#
# iv. Drop Duplicates rows and make this changes permanent. Show dataframe after changes.

# %%
# code here
birds[birds['birds'] == 'Cranes']['visits'].sum()
# Out:
# 14

# %%
birds['birds'].value_counts()
# Out:
# birds
# Cranes        5
# spoonbills    4
# plovers       2
# Name: count, dtype: int64

# %%
birds.duplicated().sum()
# Out:
# 1

# %%
birds.drop_duplicates(inplace=True)

# %%
birds
# Out:
#         birds       age  visits priority
# a      Cranes  3.500000       2      yes
# b      Cranes  4.000000       4      yes
# c     plovers  1.500000       3       no
# d  spoonbills  4.333333       4      NaN
# e  spoonbills  6.000000       3       no
# f      Cranes  3.000000       4       no
# g     plovers  5.500000       2       no
# h      Cranes  4.333333       2      yes
# i  spoonbills  8.000000       3       no
# j  spoonbills  4.000000       2       no

# %%
birds.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##Question on IPL Data
#
# IPL Data Link :  https://drive.google.com/file/d/1yKVUuexl6lIKuFQy7uIPgDgXhJ0L4SIg/view?usp=share_link
#
# https://www.kaggle.com/datasets/vora1011/ipl-2008-to-2021-all-match-dataset?select=IPL_Matches_2008_2022.csv
#
# Download ipl matches 2008-2022 file.

# %% [markdown]
# ###`Q-5:` In IPL matches dataset some teams name has changed.
# You will have to consider them as same.
# ```
# 'Delhi Capitals' formerly as 'Delhi Daredevils'
# 'Punjab Kings' formerly as 'Kings XI Punjab'
# 'Rising Pune Supergiant' formerly as 'Rising Pune Supergiants'
# ```
# You need to make changes accordingly. Consider current name for each teams.
#
# Be careful Gujrat Titans and Gujrat Lions are different teams.

# %%
import numpy as np
import pandas as pd

# %%
ipl = pd.read_csv('/content/IPL_Matches_2008_2022.csv')

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Mumbai Indians                 112
# Chennai Super Kings            111
# Kolkata Knight Riders          105
# Kings XI Punjab                 92
# Rajasthan Royals                89
# Delhi Daredevils                85
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Delhi Capitals                  29
# Pune Warriors                   23
# Punjab Kings                    18
# Gujarat Lions                   16
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
ipl['Team2'].value_counts()
# Out:
# Team2
# Mumbai Indians                 119
# Kolkata Knight Riders          118
# Rajasthan Royals               103
# Royal Challengers Bangalore    100
# Kings XI Punjab                 98
# Chennai Super Kings             97
# Sunrisers Hyderabad             83
# Delhi Daredevils                76
# Deccan Chargers                 36
# Delhi Capitals                  34
# Pune Warriors                   23
# Gujarat Lions                   14
# Punjab Kings                    10
# Gujarat Titans                   9
# Rising Pune Supergiant           9
# Rising Pune Supergiants          7
# Lucknow Super Giants             7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
ipl['Team1'] = ipl['Team1'].apply(lambda x: 'Delhi Capitals' if x == 'Delhi Daredevils' else x)
ipl['Team1'] = ipl['Team1'].apply(lambda x: 'Punjab Kings' if x == 'Kings XI Punjab' else x)
ipl['Team1'] = ipl['Team1'].apply(lambda x: 'Rising Pune Supergiant' if x == 'Rising Pune Supergiants' else x)

# %%
ipl['Team2'] = ipl['Team2'].apply(lambda x: 'Delhi Capitals' if x == 'Delhi Daredevils' else x)
ipl['Team2'] = ipl['Team2'].apply(lambda x: 'Punjab Kings' if x == 'Kings XI Punjab' else x)
ipl['Team2'] = ipl['Team2'].apply(lambda x: 'Rising Pune Supergiant' if x == 'Rising Pune Supergiants' else x)

# %%
ipl['Team1'].value_counts()
# Out:
# Team1
# Royal Challengers Bangalore    126
# Delhi Capitals                 114
# Mumbai Indians                 112
# Chennai Super Kings            111
# Punjab Kings                   110
# Kolkata Knight Riders          105
# Rajasthan Royals                89
# Sunrisers Hyderabad             69
# Deccan Chargers                 39
# Pune Warriors                   23
# Gujarat Lions                   16
# Rising Pune Supergiant          14
# Lucknow Super Giants             8
# Gujarat Titans                   7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %%
ipl['Team2'].value_counts()
# Out:
# Team2
# Mumbai Indians                 119
# Kolkata Knight Riders          118
# Delhi Capitals                 110
# Punjab Kings                   108
# Rajasthan Royals               103
# Royal Challengers Bangalore    100
# Chennai Super Kings             97
# Sunrisers Hyderabad             83
# Deccan Chargers                 36
# Pune Warriors                   23
# Rising Pune Supergiant          16
# Gujarat Lions                   14
# Gujarat Titans                   9
# Lucknow Super Giants             7
# Kochi Tuskers Kerala             7
# Name: count, dtype: int64

# %% [markdown]
# ###`Q-6` Write a code which can display the bar chart of top 5 teams who have played maximum number of matches in the IPL.
# >  Hint: Be careful the data is divided in 2 different cols(Team 1 and Team 2)

# %%
# code here

(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False).head().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ###`Q-7:` Player who got Most no. of player of the match award playing against Mumbai Indians.
# > Just for this question assume player of the match award is given to players from winning team. Although this is true in most of the cases.

# %%
# code here

mum_t1 = ipl[ipl['Team1'] == 'Mumbai Indians']

# %%
ipl.loc[1,:].loc['Date']
# Out:
# '2022-05-27'

# %%
def pom_t2(row):
  pom = row.loc['Player_of_Match']
  if pom in row.loc['Team2Players']:
    return True
  else:
    return False

# %%
mum_t1.loc[:,'pom_t2'] = mum_t1.apply(pom_t2,axis=1)

# %%
mum_t1 = mum_t1[mum_t1['pom_t2'] == True]

# %%
mum_t2 = ipl[ipl['Team2'] == 'Mumbai Indians']

# %%
def pom_t1(row):
  pom = row.loc['Player_of_Match']
  if pom in row.loc['Team1Players']:
    return True
  else:
    return False

# %%
mum_t2.loc[:,'pom_t1'] = mum_t2.apply(pom_t1,axis=1)

# %%
mum_t2 = mum_t2[mum_t2['pom_t1'] == True]

# %%
mum_t1['Player_of_Match'].value_counts() + mum_t2['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# A Mishra             3.0
# A Nehra              3.0
# AB de Villiers       2.0
# AC Gilchrist         NaN
# AD Russell           NaN
#                     ...
# TG Southee           NaN
# V Sehwag             NaN
# WP Saha              NaN
# Washington Sundar    NaN
# YK Pathan            NaN
# Name: count, Length: 70, dtype: float64

# %%
mum_t2['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# SK Raina          4
# V Sehwag          3
# KC Sangakkara     3
# KL Rahul          2
# CH Gayle          2
# ML Hayden         2
# SPD Smith         2
# BA Bhatt          1
# Azhar Mahmood     1
# I Sharma          1
# AM Rahane         1
# MS Dhoni          1
# RA Tripathi       1
# MEK Hussey        1
# J Botha           1
# M Kartik          1
# A Nehra           1
# RG Sharma         1
# JH Kallis         1
# PP Ojha           1
# Sohail Tanvir     1
# R Sharma          1
# MM Sharma         1
# PA Patel          1
# A Mishra          1
# MA Agarwal        1
# JC Buttler        1
# GJ Maxwell        1
# RD Gaikwad        1
# AB de Villiers    1
# AD Russell        1
# RR Pant           1
# TG Southee        1
# M Vijay           1
# Rashid Khan       1
# S Dhawan          1
# SV Samson         1
# DA Warner         1
# SS Iyer           1
# M Morkel          1
# RV Uthappa        1
# KD Karthik        1
# Name: count, dtype: int64

# %%
mum_t1['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# A Nehra              2
# SP Narine            2
# KL Rahul             2
# A Mishra             2
# S Nadeem             2
# BA Stokes            2
# JH Kallis            2
# SPD Smith            2
# JC Buttler           2
# SE Marsh             2
# CH Gayle             1
# AB de Villiers       1
# GJ Bailey            1
# DR Smith             1
# B Kumar              1
# Mukesh Choudhary     1
# DW Steyn             1
# AM Rahane            1
# BB McCullum          1
# YK Pathan            1
# SK Warne             1
# AC Gilchrist         1
# SR Watson            1
# Washington Sundar    1
# AJ Finch             1
# MP Stoinis           1
# WP Saha              1
# Anuj Rawat           1
# DJ Bravo             1
# Rashid Khan          1
# JJ Roy               1
# JC Archer            1
# MA Agarwal           1
# AT Rayudu            1
# HV Patel             1
# AR Patel             1
# Kuldeep Yadav        1
# PJ Cummins           1
# MV Boucher           1
# ...

# %%
mum_t2['Player_of_Match'].value_counts().add(mum_t1['Player_of_Match'].value_counts(),fill_value=0).sort_values(ascending=False)
# Out:
# Player_of_Match
# SPD Smith        4.0
# SK Raina         4.0
# KL Rahul         4.0
# A Nehra          3.0
# KC Sangakkara    3.0
#                 ...
# Kuldeep Yadav    1.0
# M Kartik         1.0
# M Morkel         1.0
# MEK Hussey       1.0
# YK Pathan        1.0
# Name: count, Length: 70, dtype: float64

# %% [markdown]
# ###`Q-8:` Team1 vs Team2 Dashbord
# Create a function which will take two string(name of two teams) as input. Show win Loss record between them and player getting most player of the match award in matches between these two teams.
# ```
# team1_vs_team2('Kolkata Knight Riders','Chennai Super Kings')
# ```

# %%
# code here

# %% [markdown]
# ### `Q-9:` Find out the top 7 cities where the matches of Kolkata Knight Riders are played frequently and plot the result as bar chart.
#
# *`.plot(kind = "bar")` can help you to plot the bar chart. Also you can learn more about this method from [here](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)*

# %%
# code here

# %% [markdown]
# ### `Q-10:` Find out the average margin for the team Mumbai Indians for only the session 2011.

# %%
# code here
